# %% [markdown]
# <a href="https://colab.research.google.com/github/chunkyshrapnel/Oregon_Project/blob/main/Copy_of_oregon_projv2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ee
ee.Authenticate()
ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=QSCYKF_9jKb1sicHb-5BbEo4cSVsWGa8KC507FL9pS8&tc=1nEHZ6ZUBH-x2a00GwjITZ0vqGfnDPiLsyO1X46wsLQ&cc=-mx-ayz3OrLkOvBJgDEk0c4GLCcGBSYIW52-gfod9FQ
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1Adeu5BUSWMBxxSvTcQuPgBUv2I9LBltU6Ul6BKYcFCKLgYSsyoFAsx_N9nE
#
# Successfully saved authorization token.

# %%
# This will be the UI
import time
import ee
#ee.Authenticate()
ee.Initialize()

def main():

  # Set default values for exporting
  start_date = '2002-01-01'
  end_date = '2002-12-01'
  model = 'disalexi'
  boundary_name, boundary = get_boundary_geometry()
  image_coll = ee.ImageCollection\
   ('projects/openet/disalexi/conus/gridmet/monthly/provisional').\
   filterDate(start_date, end_date)

  # Loop runs until an export call is made.
  # Everytime a value is changed, the menu is displayed again.
  while(True):

    # Dispaly menu to console
    print_menu(model, start_date, end_date, boundary_name)

    # Get user input and pass on to match statement
    selected_menu_option = input()

    match selected_menu_option:

      case 'y':

        # all images are mosaiced and exported
        export_handler(image_coll,start_date, end_date, boundary, model)

        # Terminate loop and end program
        break;

      case '1':

        print_model_menu()
        model, image_coll = change_model()
        image_coll = filter_bands_and_dates(image_coll, start_date, end_date)

      case '2':

        print("Enter start date in form: yyyy-mm-dd")
        start_date = input()

      case '3':

        print("Enter end date in form: yyyy-mm-dd")
        end_date = input()

      case _:

          print('ERROR: Invalid Input')


def print_menu(model, start_date, end_date, boundary):

  print("\nEnter a number to change the export option.")
  print("##################################################")
  print("1 - MODEL: ", model)
  print("2 - START DATE: ", start_date)
  print("3 - END DATE: ", end_date)
  print("4 - Boundary: ", boundary + "(NOT CHANGEABLE AT THIS TIME)")
  print("\nEnter 'y' to export image collection.")


# This function is a place holder for when the user can pic their own geometry
def get_boundary_geometry():

  states = ee.FeatureCollection('TIGER/2018/States')
  boundary = states.filter(ee.Filter.eq('GEOID', '41'))

  return "Oregon State Boundary", boundary


# This function mosaics images and initaites exporting all images
def export_handler(image_coll,start_date, end_date, boundary, model):
      image_coll = mosaci_all_images(image_coll)
      print("POST MOSAIC: ", image_coll.length().getInfo())
      print(image_coll.getInfo())
      for i in range(image_coll.length().getInfo()):

        export_tif(image_coll.get(i),start_date, end_date, boundary, model);


def print_model_menu():

        print("\nEnter a number to change the model.")
        print("##################################################")
        print("1 - DisALEXI")
        print("2 - eeMETRIC")
        print("3 - geeSEBAL")
        print("4 - PT-JPL")
        print("5 - SIMS ")
        print("6 - SSEBop")
        print("7 - Ensemble")


def change_model():

      user_input = input()

      match user_input:

        case '1':

            return 'disalexi', ee.ImageCollection('projects/openet/disalexi/conus/gridmet/monthly/provisional')

        case '2':

            return 'eemetric', ee.ImageCollection('projects/openet/eemetric/conus/gridmet/monthly/provisional')

        case '3':

            return 'geesebal', ee.ImageCollection('projects/openet/geesebal/conus/gridmet/monthly/provisional')

        case '4':

            return 'ptjpl', ee.ImageCollection('projects/openet/ptjpl/conus/gridmet/monthly/provisional')

        case '5':

            return 'sims', ee.ImageCollection('projects/openet/sims/conus/gridmet/monthly/provisional')

        case '6':

            return 'ssebop', ee.ImageCollection('projects/openet/ssebop/conus/gridmet/monthly/provisional')

        case '7':

            return 'ensemble', ee.ImageCollection('projects/openet/ensemble/conus/gridmet/monthly/provisional')

        case _:

            print('ERROR: Invalid Input')


def filter_bands_and_dates(image_coll, start_date, end_date):

  image_coll = image_coll.filterDate(start_date, end_date)

  # Remove all bands but the first one
  image_coll = image_coll.select(0)

  return image_coll


# This is the helper function that performs necessary maniplation and
# calls the fucntion that mosaics the 10T and 11T pairs.
def mosaci_all_images(image_coll):

  # Remove all images that are not in 10T or 11T
  image_coll = image_coll.filter(ee.Filter.inList('mgrs_tile', ['10T','11T']))
  print("PRE MOSAIC: ", image_coll.size().getInfo())
  print(image_coll.getInfo())
  # hacky list manipulation.
  # Convert to list and get size of list/2
  to_list = image_coll.toList(image_coll.size());
  size_of_sub_list = to_list.size().divide(2);

  # Splits the list into 2 listst where all the 10T and 11T images have theeir own list
  ten_t_list = to_list.splice(size_of_sub_list, size_of_sub_list)       # EPSG:32610 T10
  eleven_t_list = to_list.splice(0, size_of_sub_list)                   # EPSG:32611 T11

  # combine the two sepearte lists into one list of list pairs
  combinations = ten_t_list.zip(eleven_t_list);

  return combinations.map(mosaic_image_pairs)


# Takes each pair of images(10T and 11T) and mosaics them.
def mosaic_image_pairs(lst):

  lst = ee.List(lst);

  my_id = ee.Image(lst.get(0)).id().slice(4);

  # crs: EPSG:4326 (not real?)
  new_mosaic = ee.Image(ee.ImageCollection([lst.get(0), lst.get(1)]).mosaic()).set("system:index",my_id)

  return new_mosaic;


def export_tif(img,start_date, end_date, boundary, model):

  # clip so that idahoe and washington data is left out
  img = ee.Image(img);
  img = img.clip(boundary.geometry());

  # convert all bands to unsigned int16. If types are not consistent than an error is thrown.
  img = img.toUint16();

  # Create file path
  path = 'oregon/' + model + '_' + start_date + '_' + end_date + '/' + img.id().getInfo()

  # Export to Google bucket as a .tif file. (GeoTIFF)
  task = ee.batch.Export.image.toCloudStorage(**{
    'image': img,
    #description: path,
    'bucket': 'openet_temp',
    'fileNamePrefix': path,
    'crs': img.projection(),
    #'crsTransform': [30, 0, 239985, 0, -30, 5299995],
    'scale': 30,
    'region': boundary.geometry(),
    'maxPixels': 1e13,
    'fileDimensions' : 51200

  })

  #task.start()

  while task.active():
    print('Polling for task (id: {0}) - Image:{1}.'.format(task.id, img.id().getInfo()))
    time.sleep(15)


main()
# Out:
# Enter a number to change the export option.
# ##################################################
# 1 - MODEL:  disalexi
# 2 - START DATE:  2002-01-01
# 3 - END DATE:  2002-12-01
# 4 - Boundary:  Oregon State Boundary(NOT CHANGEABLE AT THIS TIME)
#
# Enter 'y' to export image collection.
# y
# PRE MOSAIC:  22
# {'type': 'ImageCollection', 'bands': [], 'version': 1691298708422708, 'id': 'projects/openet/disalexi/conus/gridmet/monthly/provisional', 'features': [{'type': 'Image', 'bands': [{'id': 'et', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [15333, 30000], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 299985, 0, -30, 5299995]}, {'id': 'count', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [15333, 30000], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 299985, 0, -30, 5299995]}], 'id': 'projects/openet/disalexi/conus/gridmet/monthly/provisional/10t_20020101_20020131', 'version': 1687129310023276, 'properties': {'end_date': '2002-01-31', 'scale_factor_count': 1, 'model_version': '0.0.33', 'alexi_source_count': 31, 'interp_method': 'LINEAR', 'model_name': 'DISALEXI', 'cloud_cover_max': 70, 'collections': 'LANDSAT/LC08/C02/T1_L2, LANDSAT/LE07/C02/T1_L2, LANDSAT/LT05/C02/T1_L2', 'tool_version': '0.2.1', 'system:footprint': {'type': 'LinearRing', 'coordinates': [[-125.46487820682786, 43.26998363193655], [-125.4250521716291, 42.25782673986441], [-125.3872228596503, 41.24546154721181], [-125.33396550108901, 39.72625893961845], [-119.96723239175992, 39.71009621524534], [-119.89808386731161, 41.228413443002985], [-119.84896934420433, 42.24016571430355], [-119.79726431446075, 43.25168998646454], [-119.74280683933388, 44.26298236907969], [-119.68541978828443, 45.274039040399046], [-119.62490956714988, 46.284855907286136], [-119.52780065064775, 47.80089189098351], [-122.59923803211709, 47.85273249829822], [-125.67246117414936, 47.82231633573941], [-125.59764733724847, 46.30518007973121], [-125.50682616264827, 44.28192973914144], [-125.46487820682786, 43.26998363193655]]}, 'interp_source_count': 31, 'start_date': '2002-01-01', 'tool_name': 'scene_interpolate_mgrs_export', 'interp_days': 32, 'scale_factor_et': 1, 'mgrs_tile': '10T', 'core_version': '0.1.0', 'system:time_start': 1009843200000, 'et_reference_resample': 'nearest', 'et_reference_band': 'eto', 'alexi_source': 'projects/ee-tulipyangyun-2/assets/alexi/ALEXI_V006', 'date_ingested': '2023-06-18', 'et_reference_factor': 1, 'et_reference_source': 'projects/earthengine-legacy/assets/projects/openet/reference_et/gridmet/daily', 'system:asset_size': 223447360, 'system:index': '10t_20020101_20020131'}}, {'type': 'Image', 'bands': [{'id': 'et', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [15333, 30000], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 299985, 0, -30, 5299995]}, {'id': 'count', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [15333, 30000], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 299985, 0, -30, 5299995]}], 'id': 'projects/openet/disalexi/conus/gridmet/monthly/provisional/10t_20020201_20020228', 'version': 1687128827933390.0, 'properties': {'end_date': '2002-02-28', 'scale_factor_count': 1, 'model_version': '0.0.33', 'alexi_source_count': 28, 'interp_method': 'LINEAR', 'model_name': 'DISALEXI', 'cloud_cover_max': 70, 'collections': 'LANDSAT/LC08/C02/T1_L2, LANDSAT/LE07/C02/T1_L2, LANDSAT/LT05/C02/T1_L2', 'tool_version': '0.2.1', 'system:footprint': {'type': 'LinearRing', 'coordinates': [[-125.46487820682786, 43.26998363193655], [-125.4250521716291, 42.25782673986441], [-125.3872228596503, 41.24546154721181], [-125.33396550108901, 39.72625893961845], [-119.96723239175992, 39.71009621524534], [-119.89808386731161, 41.228413443002985], [-119.84896934420433, 42.24016571430355], [-119.79726431446075, 43.25168998646454], [-119.74280683933388, 44.26298236907969], [-119.68541978828443, 45.274039040399046], [-119.62490956714988, 46.284855907286136], [-119.52780065064775, 47.80089189098351], [-122.59923803211709, 47.85273249829822], [-125.67246117414936, 47.82231633573941], [-125.59764733724847, 46.30518007973121], [-125.50682616264827, 44.28192973914144], [-125.46487820682786, 43.26998363193 ...
# POST MOSAIC:  11
# [{'type': 'Image', 'bands': [{'id': 'et', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'count', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '20020101_20020131'}}, {'type': 'Image', 'bands': [{'id': 'et', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'count', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '20020201_20020228'}}, {'type': 'Image', 'bands': [{'id': 'et', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'count', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '20020301_20020331'}}, {'type': 'Image', 'bands': [{'id': 'et', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'count', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '20020401_20020430'}}, {'type': 'Image', 'bands': [{'id': 'et', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'count', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '20020501_20020531'}}, {'type': 'Image', 'bands': [{'id': 'et', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'count', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '20020601_20020630'}}, {'type': 'Image', 'bands': [{'id': 'et', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'count', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '20020701_20020731'}}, {'type': 'Image', 'bands': [{'id': 'et', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'count', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '20020801_20020831'}}, {'type': 'Image', 'bands': [{'id': 'et', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'count', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '20020901_20020930'}}, {'type': 'Image', 'bands': [{'id': 'et', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'count', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'system:index': '20021001_20021031'}}, {'type': 'Image', 'bands': [{'id': 'et', 'data_type': {'type': 'PixelType', 'precision':  ...
